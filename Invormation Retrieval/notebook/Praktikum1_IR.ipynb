# %%
# menghubungkan colab dengan google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# memanggil data set lewat gdrive
path = "/content/drive/MyDrive/IR/data"

# %%
# Membaca File kompas.xml
import pandas as pd

df = pd.read_xml(path + "/kompas.xml")
df.head()
# Out:
#        sumber     tanggal   kategori  \
# 0  kompas.com  2015/07/01  Teknologi
# 1  kompas.com  2015/07/01  Teknologi
# 2  kompas.com  2015/07/01  Teknologi
# 3  kompas.com  2015/07/01  Teknologi
# 4  kompas.com  2015/07/01  Teknologi
#
#                                                judul  \
# 0      Ponsel Huawei Honor 4C Dibanderol Rp 2,2 Juta
# 1  Asosiasi: RPP E-commerce Tidak Sesuai Hasil Di...
# 2  Pemesan "iPhone Jadi Sabun" Karyawan Pesaing L...
# 3  "Autofeather Failure", Momok bagi Pesawat Bali...
# 4     Laptop Bezel Tertipis di Dunia Masuk Indonesia
#
#                                                  isi  \
# 0  JAKARTA, KOMPAS.com  Ponsel Android Huawei Hon...
# 1  JAKARTA, KOMPAS.com - Sejak 2013, wacana tenta...
# 2  JAKARTA, KOMPAS.com Danis Darusman, pelanggan ...
# 3  KOMPAS.com Salah satu momok yang dihadapi dala...
# 4  JAKARTA, KOMPAS.com - Resmi diperkenalkan pada...
#
#                                                 link  jumlahkata
# 0  http://tekno.kompas.com/read/xml/2015/07/01/18...         315
# 1  http://tekno.kompas.com/read/xml/2015/07/01/16...         419
# 2  http://tekno.kompas.com/read/xml/2015/07/01/15...         265
# 3  http://tekno.kompas.com/read/xml/2015/07/01/14...         481
# 4  http://tekno.kompas.com/read/xml/2015/07/01/14...         227

# %%
# Mencari Informasi Data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1502 entries, 0 to 1501
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   sumber      1502 non-null   object
#  1   tanggal     1502 non-null   object
#  2   kategori    1502 non-null   object
#  3   judul       1502 non-null   object
#  4   isi         1502 non-null   object
#  5   link        1502 non-null   object
#  6   jumlahkata  1502 non-null   int64
# dtypes: int64(1), object(6)
# memory usage: 82.3+ KB

# %%
# Memeriksa nilai NaN dan Duplikat
df.isnull().sum()
# Out:
# sumber        0
# tanggal       0
# kategori      0
# judul         0
# isi           0
# link          0
# jumlahkata    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Case Folding
def caseFolding(text):
    text = text.lower()
    return text

contoh ="Terima kasih, kak! Kamu sangat baik sekali kepadaku hari ini."
print(f'Original Text: {contoh}')
print(f'case Folding Text: {caseFolding(contoh)}')
# Out:
# Original Text: Terima kasih, kak! Kamu sangat baik sekali kepadaku hari ini.
# case Folding Text: terima kasih, kak! kamu sangat baik sekali kepadaku hari ini.

# %%
# Punctuation Removal
import re

def punctuationRemoval(text):
    text = re.sub(r'[^\w\s]', '', text)
    return text

contoh = "Terima kasih, kak! Kamu sangat baik sekali kepadaku hari ini."
print(f'Original Text: {contoh}')
print(f'Punctuation Removal Text: {punctuationRemoval(contoh)}')
# Out:
# Original Text: Terima kasih, kak! Kamu sangat baik sekali kepadaku hari ini.
# Punctuation Removal Text: Terima kasih kak Kamu sangat baik sekali kepadaku hari ini

# %%
# Menerapkan Function
df['clean'] = df['isi'].apply(caseFolding)
df['clean'] = df['clean'].apply(punctuationRemoval)
df.head()
# Out:
#        sumber     tanggal   kategori  \
# 0  kompas.com  2015/07/01  Teknologi
# 1  kompas.com  2015/07/01  Teknologi
# 2  kompas.com  2015/07/01  Teknologi
# 3  kompas.com  2015/07/01  Teknologi
# 4  kompas.com  2015/07/01  Teknologi
#
#                                                judul  \
# 0      Ponsel Huawei Honor 4C Dibanderol Rp 2,2 Juta
# 1  Asosiasi: RPP E-commerce Tidak Sesuai Hasil Di...
# 2  Pemesan "iPhone Jadi Sabun" Karyawan Pesaing L...
# 3  "Autofeather Failure", Momok bagi Pesawat Bali...
# 4     Laptop Bezel Tertipis di Dunia Masuk Indonesia
#
#                                                  isi  \
# 0  JAKARTA, KOMPAS.com  Ponsel Android Huawei Hon...
# 1  JAKARTA, KOMPAS.com - Sejak 2013, wacana tenta...
# 2  JAKARTA, KOMPAS.com Danis Darusman, pelanggan ...
# 3  KOMPAS.com Salah satu momok yang dihadapi dala...
# 4  JAKARTA, KOMPAS.com - Resmi diperkenalkan pada...
#
#                                                 link  jumlahkata  \
# 0  http://tekno.kompas.com/read/xml/2015/07/01/18...         315
# 1  http://tekno.kompas.com/read/xml/2015/07/01/16...         419
# 2  http://tekno.kompas.com/read/xml/2015/07/01/15...         265
# 3  http://tekno.kompas.com/read/xml/2015/07/01/14...         481
# 4  http://tekno.kompas.com/read/xml/2015/07/01/14...         227
#
#                                                clean
# 0  jakarta kompascom  ponsel android huawei honor...
# 1  jakarta kompascom  sejak 2013 wacana tentang r...
# 2  jakarta kompascom danis darusman pelanggan laz...
# 3  kompascom salah satu momok yang dihadapi dalam...
# 4  jakarta kompascom  resmi diperkenalkan pada aj...

# %%
# Membuat Function Tokenisasi
def tokenize(text):
    return text.split(" ")

contoh = "terima kasih kak kamu sangat baik sekali kepadaku hari ini"
print(f'Original Text: {contoh}')

clean = caseFolding(contoh)
clean = punctuationRemoval(clean)
print(f'Tokenized: {tokenize(clean)}')
# Out:
# Original Text: terima kasih kak kamu sangat baik sekali kepadaku hari ini
# Tokenized: ['terima', 'kasih', 'kak', 'kamu', 'sangat', 'baik', 'sekali', 'kepadaku', 'hari', 'ini']

# %%
# Menerapkan Function
df['tokens'] = df['clean'].apply(tokenize)
df.head()
# Out:
#        sumber     tanggal   kategori  \
# 0  kompas.com  2015/07/01  Teknologi
# 1  kompas.com  2015/07/01  Teknologi
# 2  kompas.com  2015/07/01  Teknologi
# 3  kompas.com  2015/07/01  Teknologi
# 4  kompas.com  2015/07/01  Teknologi
#
#                                                judul  \
# 0      Ponsel Huawei Honor 4C Dibanderol Rp 2,2 Juta
# 1  Asosiasi: RPP E-commerce Tidak Sesuai Hasil Di...
# 2  Pemesan "iPhone Jadi Sabun" Karyawan Pesaing L...
# 3  "Autofeather Failure", Momok bagi Pesawat Bali...
# 4     Laptop Bezel Tertipis di Dunia Masuk Indonesia
#
#                                                  isi  \
# 0  JAKARTA, KOMPAS.com  Ponsel Android Huawei Hon...
# 1  JAKARTA, KOMPAS.com - Sejak 2013, wacana tenta...
# 2  JAKARTA, KOMPAS.com Danis Darusman, pelanggan ...
# 3  KOMPAS.com Salah satu momok yang dihadapi dala...
# 4  JAKARTA, KOMPAS.com - Resmi diperkenalkan pada...
#
#                                                 link  jumlahkata  \
# 0  http://tekno.kompas.com/read/xml/2015/07/01/18...         315
# 1  http://tekno.kompas.com/read/xml/2015/07/01/16...         419
# 2  http://tekno.kompas.com/read/xml/2015/07/01/15...         265
# 3  http://tekno.kompas.com/read/xml/2015/07/01/14...         481
# 4  http://tekno.kompas.com/read/xml/2015/07/01/14...         227
#
#                                                clean  \
# 0  jakarta kompascom  ponsel android huawei honor...
# 1  jakarta kompascom  sejak 2013 wacana tentang r...
# 2  jakarta kompascom danis darusman pelanggan laz...
# 3  kompascom salah satu momok yang dihadapi dalam...
# 4  jakarta kompascom  resmi diperkenalkan pada aj...
#
#                                               tokens
# 0  [jakarta, kompascom, , ponsel, android, huawei...
# 1  [jakarta, kompascom, , sejak, 2013, wacana, te...
# 2  [jakarta, kompascom, danis, darusman, pelangga...
# 3  [kompascom, salah, satu, momok, yang, dihadapi...
# 4  [jakarta, kompascom, , resmi, diperkenalkan, p...

# %%
# Frekuensi Kata
from collections import Counter

all_token = []

for tokens in df['tokens']:
    if isinstance(tokens, list):
        for token in tokens:
            token = str(token).strip()
            if token:
                all_token.append(token)

# Hitung Frekuensi
term_freq = Counter(all_token)

# Buat dataframe
term_freq_df = pd.DataFrame(term_freq.items(), columns=['term', 'freq'])

# Sorting/Urutkan dari tertinggi
term_freq_df_sorted = term_freq_df.sort_values(by='freq', ascending=False, ignore_index=True)

term_freq_df_sorted.head(10)
# Out:
#      term  freq
# 0    yang  6450
# 1      di  5824
# 2     dan  4915
# 3     ini  2744
# 4  dengan  2625
# 5   untuk  2583
# 6    dari  2460
# 7     itu  2437
# 8    akan  2055
# 9   dalam  1743

# %%
# Urutkan dari frekuensi kecil ke besar
term_freq_df_sorted = term_freq_df.sort_values(by='freq', ascending=True, ignore_index=True)

# Hitung rank ulang berdasarkan urutan baru
term_freq_df_sorted['rank'] = range(1, len(term_freq_df_sorted) + 1)

# Lihat 10 data teratas
term_freq_df_sorted.head(10)
# Out:
#                term  freq  rank
# 0           batunya     1     1
# 1            salome     1     2
# 2     kesehariannya     1     3
# 3            antero     1     4
# 4           permata     1     5
# 5           booming     1     6
# 6  tribunnewsreynas     1     7
# 7            reynas     1     8
# 8        tribunnews     1     9
# 9           nyengat     1    10

# %%
# Rank
term_freq_df_sorted['rank'] = term_freq_df_sorted['freq'].rank(method='first', ascending=False).astype(int)
term_freq_df_sorted.head()
# Out:
#             term  freq   rank
# 0        batunya     1  12216
# 1         salome     1  12217
# 2  kesehariannya     1  12218
# 3         antero     1  12219
# 4        permata     1  12220

# %%
# Mengurutkan Berdasarkan Rank
tf_df = term_freq_df_sorted.copy()
tf_df.rename(columns={'freq': 'Freq (ft, d)'}, inplace=True)

tf_df['Rank'] = tf_df['Freq (ft, d)'].rank(method='first', ascending=False).astype(int)

tf_sorted_rank = tf_df.sort_values(by='Rank', ascending=True)
tf_sorted_rank.head(20)
# Out:
#            term  Freq (ft, d)  rank  Rank
# 24854      yang          6450     1     1
# 24853        di          5824     2     2
# 24852       dan          4915     3     3
# 24851       ini          2744     4     4
# 24850    dengan          2625     5     5
# 24849     untuk          2583     6     6
# 24848      dari          2460     7     7
# 24847       itu          2437     8     8
# 24846      akan          2055     9     9
# 24845     dalam          1743    10    10
# 24844      pada          1625    11    11
# 24843   pesawat          1600    12    12
# 24842     tidak          1513    13    13
# 24841        ke          1428    14    14
# 24840  tersebut          1300    15    15
# 24839      juga          1245    16    16
# 24838       tni          1174    17    17
# 24837       ada          1127    18    18
# 24836      kata          1105    19    19
# 24835     sudah          1091    20    20

# %%
# Zip Flaw
term_freq_df_sorted['k = f * r'] = term_freq_df_sorted['freq'] * term_freq_df_sorted['rank']
term_freq_df_sorted.head(100)
# Out:
#              term  freq   rank  k = f * r
# 0         batunya     1  12216      12216
# 1          salome     1  12217      12217
# 2   kesehariannya     1  12218      12218
# 3          antero     1  12219      12219
# 4         permata     1  12220      12220
# ..            ...   ...    ...        ...
# 95    magnificent     1  12311      12311
# 96        memikul     1  12312      12312
# 97     menjajakan     1  12313      12313
# 98         lampau     1  12314      12314
# 99            cah     1  12315      12315
#
# [100 rows x 4 columns]

# %%
# Term Frequency & Penerapan Zipf’s Law
import matplotlib.pyplot as plt

rank = term_freq_df_sorted['rank']
freq = term_freq_df_sorted['freq']
plt.figure(figsize=(10, 5))
plt.scatter(rank, freq, color='red', s=10)
plt.title("Term Frequency vs Rank")
plt.xlabel("rank")
plt.ylabel("frekuensi (f)")

plt.grid(True)
plt.show()
